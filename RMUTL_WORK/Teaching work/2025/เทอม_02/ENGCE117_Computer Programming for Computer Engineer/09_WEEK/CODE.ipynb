# %%
def __str__(self):
    return f"Vector({self.x}, {self.y})"

# การเรียกใช้งาน
v = Vector(3, 4)
print(v) 

# ผลลัพธ์: Vector(3, 4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2     return f"Vector({self.x}, {self.y})"
#       4 # การเรียกใช้งาน
# ----> 5 v = Vector(3, 4)
#       6 print(v)
#       8 # ผลลัพธ์: Vector(3, 4)
#
# NameError: name 'Vector' is not defined
