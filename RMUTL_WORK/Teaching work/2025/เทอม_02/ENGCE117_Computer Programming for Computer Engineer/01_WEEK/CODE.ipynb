# %%
x = 10          # x เป็น integer โดยอัตโนมัติ
name = "Engineer" # name เป็น string
pi = 3.14       # pi เป็น float
is_valid = True # is_valid เป็น boolean

# %%
score = 75
if score >= 80:
    print("Grade A")
elif score >= 70:
    print("Grade B")
else:
    print("Grade C")

# %%
count = 5
while count > 0:
    print(f"Countdown: {count}")
    count -= 1
print("Blast off!")

# %%
for i in range(5):  # วน 5 รอบ (i = 0, 1, 2, 3, 4)
    print(i)

# %%
for i in range(10):
    if i == 3:
        continue  # ข้ามเลข 3
    if i == 8:
        break     # หยุดเมื่อถึงเลข 8
    print(i, end=" ")
# Output: 0 1 2 4 5 6 7

# %%
def function_name(parameter1, parameter2):
    # Docstring (อธิบายการทำงาน)
    """Calculates the sum of two numbers."""
    result = parameter1 + parameter2
    return result  # ส่งค่าคืน

# %%
# ไม่ตาม PEP 8
def calculateArea(length,width):
    area=length*width
    return area

# %%
# ตาม PEP 8
def calculate_area(length, width):
    """Calculates the area of a rectangle."""
    area = length * width
    return area
