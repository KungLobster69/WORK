# %%
import pandas as pd

test_json_path = 'test_vivax.json'

test_df = pd.read_json(test_json_path)
print(test_df.shape)
# Out:
# (40, 2)

# %%
df = pd.concat([test_df]).reset_index(drop=True)
df.head()
# Out:
#                                                image  \
# 0  {'checksum': 'e423f0811edb9c6c22fa6b1cb28cc826...
# 1  {'checksum': '260251dacc2aa6823a49fcbb670a15f3...
# 2  {'checksum': '46b34bc1fe1114c5ba4accbb2d912ae5...
# 3  {'checksum': 'e1924a4ea56b9722a7f000b7043c4123...
# 4  {'checksum': '342b729ba18b4d7bed11fc760f65f387...
#
#                                              objects
# 0  [{'bounding_box': {'minimum': {'r': 1283, 'c':...
# 1  [{'bounding_box': {'minimum': {'r': 1281, 'c':...
# 2  [{'bounding_box': {'minimum': {'r': 1970, 'c':...
# 3  [{'bounding_box': {'minimum': {'r': 1960, 'c':...
# 4  [{'bounding_box': {'minimum': {'r': 1312, 'c':...

# %%
df["checksum"] = df['image'].apply(lambda x: x["checksum"])
df["pathname"] = df['image'].apply(lambda x: x["pathname"][1:])
df["shape"] = df['image'].apply(lambda x: x["shape"])
df.head()
# Out:
#                                                image  \
# 0  {'checksum': 'e423f0811edb9c6c22fa6b1cb28cc826...
# 1  {'checksum': '260251dacc2aa6823a49fcbb670a15f3...
# 2  {'checksum': '46b34bc1fe1114c5ba4accbb2d912ae5...
# 3  {'checksum': 'e1924a4ea56b9722a7f000b7043c4123...
# 4  {'checksum': '342b729ba18b4d7bed11fc760f65f387...
#
#                                              objects  \
# 0  [{'bounding_box': {'minimum': {'r': 1283, 'c':...
# 1  [{'bounding_box': {'minimum': {'r': 1281, 'c':...
# 2  [{'bounding_box': {'minimum': {'r': 1970, 'c':...
# 3  [{'bounding_box': {'minimum': {'r': 1960, 'c':...
# 4  [{'bounding_box': {'minimum': {'r': 1312, 'c':...
#
#                            checksum                          pathname  \
# 0  e423f0811edb9c6c22fa6b1cb28cc826    ivax/img/1703121298-0006-R.jpg
# 1  260251dacc2aa6823a49fcbb670a15f3    ivax/img/1709041080-0034-R.jpg
# 2  46b34bc1fe1114c5ba4accbb2d912ae5    ivax/img/1709041080-0024-R.jpg
# 3  e1924a4ea56b9722a7f000b7043c4123    ivax/img/1703121298-0008-G.jpg
# 4  342b729ba18b4d7bed11fc760f65f387  ivax/img/1709041080-0036-S_R.jpg
#
#                                    shape
# 0  {'r': 1944, 'c': 2592, 'channels': 3}
# 1  {'r': 1944, 'c': 2592, 'channels': 3}
# 2  {'r': 1944, 'c': 2592, 'channels': 3}
# 3  {'r': 1944, 'c': 2592, 'channels': 3}
# 4  {'r': 1944, 'c': 2592, 'channels': 3}

# %%
 df = pd.DataFrame(
    [
     dict(pathname=row['pathname'], 
          shape=row['shape'],
          checksum=row['checksum'],
          **bb_info) 
     for _, row in df.iterrows() 
     for bb_info in row['objects']
     ]
     )
df
# Out:
#                             pathname                                  shape  \
# 0     ivax/img/1703121298-0006-R.jpg  {'r': 1944, 'c': 2592, 'channels': 3}
# 1     ivax/img/1703121298-0006-R.jpg  {'r': 1944, 'c': 2592, 'channels': 3}
# 2     ivax/img/1703121298-0006-R.jpg  {'r': 1944, 'c': 2592, 'channels': 3}
# 3     ivax/img/1703121298-0006-R.jpg  {'r': 1944, 'c': 2592, 'channels': 3}
# 4     ivax/img/1703121298-0006-R.jpg  {'r': 1944, 'c': 2592, 'channels': 3}
# ...                              ...                                    ...
# 2685  ivax/img/1703121298-0016-G.jpg  {'r': 1944, 'c': 2592, 'channels': 3}
# 2686  ivax/img/1703121298-0016-G.jpg  {'r': 1944, 'c': 2592, 'channels': 3}
# 2687  ivax/img/1703121298-0016-G.jpg  {'r': 1944, 'c': 2592, 'channels': 3}
# 2688  ivax/img/1703121298-0016-G.jpg  {'r': 1944, 'c': 2592, 'channels': 3}
# 2689  ivax/img/1703121298-0016-G.jpg  {'r': 1944, 'c': 2592, 'channels': 3}
#
#                               checksum  \
# 0     e423f0811edb9c6c22fa6b1cb28cc826
# 1     e423f0811edb9c6c22fa6b1cb28cc826
# 2     e423f0811edb9c6c22fa6b1cb28cc826
# 3     e423f0811edb9c6c22fa6b1cb28cc826
# 4     e423f0811edb9c6c22fa6b1cb28cc826
# ...                                ...
# 2685  133859b809adc68193fb702766ded2c2
# 2686  133859b809adc68193fb702766ded2c2
# 2687  133859b809adc68193fb702766ded2c2
# 2688  133859b809adc68193fb702766ded2c2
# 2689  133859b809adc68193fb702766ded2c2
#
#                                            bounding_box        category
# 0     {'minimum': {'r': 1283, 'c': 465}, 'maximum': ...            ring
# 1     {'minimum': {'r': 1356, 'c': 1163}, 'maximum':...            ring
# 2     {'minimum': {'r': 756, 'c': 740}, 'maximum': {...  red blood cell
# 3     {'minimum': {'r': 462, 'c': 772}, 'maximum': {...  red blood cell
# 4     {'minimum': {'r': 764, 'c': 922}, 'maximum': {...  red blood cell
# ...                                                 ...             ...
# 2685  {'minimum': {'r': 1258, 'c': 15}, 'maximum': {...  red blood cell
# 2686  {'minimum': {'r': 289, 'c': 601}, 'maximum': {...  red blood cell
# 2687  {'minimum': {'r': 602, 'c': 1359}, 'maximum': ...  red blood cell
# 2688  {'minimum': {'r': 2239, 'c': 1738}, 'maximum':...  red blood cell
# 2689  {'minimum': {'r': 1966, 'c': 1767}, 'maximum':...  red blood cell
#
# [2690 rows x 5 columns]

# %%
def extract_nested_list(it):
    if isinstance(it, list):
        for sub_it in it:
            yield from extract_nested_list(sub_it)
    elif isinstance(it, dict):
        for value in it.values():
            yield from extract_nested_list(value)
    else:
        yield it

# %%
df
# Out:
#                             pathname                                  shape  \
# 0     ivax/img/1703121298-0006-R.jpg  {'r': 1944, 'c': 2592, 'channels': 3}
# 1     ivax/img/1703121298-0006-R.jpg  {'r': 1944, 'c': 2592, 'channels': 3}
# 2     ivax/img/1703121298-0006-R.jpg  {'r': 1944, 'c': 2592, 'channels': 3}
# 3     ivax/img/1703121298-0006-R.jpg  {'r': 1944, 'c': 2592, 'channels': 3}
# 4     ivax/img/1703121298-0006-R.jpg  {'r': 1944, 'c': 2592, 'channels': 3}
# ...                              ...                                    ...
# 2685  ivax/img/1703121298-0016-G.jpg  {'r': 1944, 'c': 2592, 'channels': 3}
# 2686  ivax/img/1703121298-0016-G.jpg  {'r': 1944, 'c': 2592, 'channels': 3}
# 2687  ivax/img/1703121298-0016-G.jpg  {'r': 1944, 'c': 2592, 'channels': 3}
# 2688  ivax/img/1703121298-0016-G.jpg  {'r': 1944, 'c': 2592, 'channels': 3}
# 2689  ivax/img/1703121298-0016-G.jpg  {'r': 1944, 'c': 2592, 'channels': 3}
#
#                               checksum  \
# 0     e423f0811edb9c6c22fa6b1cb28cc826
# 1     e423f0811edb9c6c22fa6b1cb28cc826
# 2     e423f0811edb9c6c22fa6b1cb28cc826
# 3     e423f0811edb9c6c22fa6b1cb28cc826
# 4     e423f0811edb9c6c22fa6b1cb28cc826
# ...                                ...
# 2685  133859b809adc68193fb702766ded2c2
# 2686  133859b809adc68193fb702766ded2c2
# 2687  133859b809adc68193fb702766ded2c2
# 2688  133859b809adc68193fb702766ded2c2
# 2689  133859b809adc68193fb702766ded2c2
#
#                                            bounding_box        category
# 0     {'minimum': {'r': 1283, 'c': 465}, 'maximum': ...            ring
# 1     {'minimum': {'r': 1356, 'c': 1163}, 'maximum':...            ring
# 2     {'minimum': {'r': 756, 'c': 740}, 'maximum': {...  red blood cell
# 3     {'minimum': {'r': 462, 'c': 772}, 'maximum': {...  red blood cell
# 4     {'minimum': {'r': 764, 'c': 922}, 'maximum': {...  red blood cell
# ...                                                 ...             ...
# 2685  {'minimum': {'r': 1258, 'c': 15}, 'maximum': {...  red blood cell
# 2686  {'minimum': {'r': 289, 'c': 601}, 'maximum': {...  red blood cell
# 2687  {'minimum': {'r': 602, 'c': 1359}, 'maximum': ...  red blood cell
# 2688  {'minimum': {'r': 2239, 'c': 1738}, 'maximum':...  red blood cell
# 2689  {'minimum': {'r': 1966, 'c': 1767}, 'maximum':...  red blood cell
#
# [2690 rows x 5 columns]

# %%
import numpy as np

df['x_min'] = -1
df['y_min'] = -1
df['x_max'] = -1
df['y_max'] = -1

df[['y_min', 'x_min', 'y_max', 'x_max']] = np.stack(df['bounding_box'].apply(lambda x: np.array(list(extract_nested_list(x)))))
df.drop(columns=['bounding_box'], inplace=True)
df['x_min'] = df['x_min'].astype(np.float)
df['y_min'] = df['y_min'].astype(np.float)
df['x_max'] = df['x_max'].astype(np.float)
df['y_max'] = df['y_max'].astype(np.float)

df['w'] = df['x_max'] - df['x_min']
df['h'] = df['y_max'] - df['y_min']

df['x_center'] = df['x_min'] + df['w'] / 2
df['y_center'] = df['y_min'] + df['h'] / 2
# Out:
# C:\Users\38658\AppData\Local\Temp/ipykernel_236292/2632202303.py:10: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df['x_min'] = df['x_min'].astype(np.float)
# C:\Users\38658\AppData\Local\Temp/ipykernel_236292/2632202303.py:11: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df['y_min'] = df['y_min'].astype(np.float)
# C:\Users\38658\AppData\Local\Temp/ipykernel_236292/2632202303.py:12: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df['x_max'] = df['x_max'].astype(np.float)
# C:\Users\38658\AppData\Local\Temp/ipykernel_236292/2632202303.py:13: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df['y_max'] = df['y_max'].astype(np.float)

# %%
df.sample(5)
# Out:
#                               pathname                                  shape  \
# 2584    ivax/img/1703121298-0010-G.jpg  {'r': 1944, 'c': 2592, 'channels': 3}
# 651   ivax/img/1703121298-0012-G_R.jpg  {'r': 1944, 'c': 2592, 'channels': 3}
# 4       ivax/img/1703121298-0006-R.jpg  {'r': 1944, 'c': 2592, 'channels': 3}
# 138     ivax/img/1709041080-0034-R.jpg  {'r': 1944, 'c': 2592, 'channels': 3}
# 619   ivax/img/1703121298-0012-G_R.jpg  {'r': 1944, 'c': 2592, 'channels': 3}
#
#                               checksum        category   x_min   y_min  \
# 2584  f35563566d458a010bcf97b73bb85ee5  red blood cell  1811.0  2229.0
# 651   0ed191a11ad910fbc2174664cb1c957a  red blood cell  1059.0  1862.0
# 4     e423f0811edb9c6c22fa6b1cb28cc826  red blood cell   922.0   764.0
# 138   260251dacc2aa6823a49fcbb670a15f3  red blood cell  1240.0   656.0
# 619   0ed191a11ad910fbc2174664cb1c957a  red blood cell   822.0  2064.0
#
#        x_max   y_max      w      h  x_center  y_center
# 2584  1661.0  2066.0 -150.0 -163.0    1736.0    2147.5
# 651   1184.0  2006.0  125.0  144.0    1121.5    1934.0
# 4     1049.0   912.0  127.0  148.0     985.5     838.0
# 138   1388.0   820.0  148.0  164.0    1314.0     738.0
# 619    963.0  2210.0  141.0  146.0     892.5    2137.0

# %%
df.shape
# Out:
# (2690, 12)

# %%
df['img_width'] = -1
df['img_height'] = -1
df['channels'] = -1
df['pixels'] = -1

df[['img_height','img_width', 'channels']] = np.stack(df['shape'].apply(lambda x: np.array(list(extract_nested_list(x)))))
df.drop(columns=['shape'], inplace=True)
df['pixels'] = df['img_width'] * df['img_height'] * df['channels']

# %%
df.shape
# Out:
# (2690, 15)

# %%
df.head()
# Out:
#                          pathname                          checksum  \
# 0  ivax/img/1703121298-0006-R.jpg  e423f0811edb9c6c22fa6b1cb28cc826
# 1  ivax/img/1703121298-0006-R.jpg  e423f0811edb9c6c22fa6b1cb28cc826
# 2  ivax/img/1703121298-0006-R.jpg  e423f0811edb9c6c22fa6b1cb28cc826
# 3  ivax/img/1703121298-0006-R.jpg  e423f0811edb9c6c22fa6b1cb28cc826
# 4  ivax/img/1703121298-0006-R.jpg  e423f0811edb9c6c22fa6b1cb28cc826
#
#          category   x_min   y_min   x_max   y_max      w      h  x_center  \
# 0            ring   465.0  1283.0   632.0  1443.0  167.0  160.0     548.5
# 1            ring  1163.0  1356.0  1319.0  1516.0  156.0  160.0    1241.0
# 2  red blood cell   740.0   756.0   892.0   908.0  152.0  152.0     816.0
# 3  red blood cell   772.0   462.0   911.0   600.0  139.0  138.0     841.5
# 4  red blood cell   922.0   764.0  1049.0   912.0  127.0  148.0     985.5
#
#    y_center  img_width  img_height  channels    pixels
# 0    1363.0       2592        1944         3  15116544
# 1    1436.0       2592        1944         3  15116544
# 2     832.0       2592        1944         3  15116544
# 3     531.0       2592        1944         3  15116544
# 4     838.0       2592        1944         3  15116544

# %%
import os
from tqdm import *

image_to_cells = {}

for index, row in tqdm(df.iterrows()):
    path_name = row['pathname']
    x_min = row['x_min']
    y_min = row['y_min']
    x_max = row['x_max']
    y_max = row['y_max']
    image_name = os.path.basename(path_name)
    if image_name not in image_to_cells:
        image_to_cells[image_name] = []
    image_to_cells[image_name].append( (x_min,y_min,x_max,y_max) )
# Out:
# 2690it [00:00, 21282.05it/s]

# %%
len(image_to_cells)
# Out:
# 40

# %%
import joblib as jl

jl.dump(image_to_cells, 'image_to_cells_labelme_vivax.jl')
# Out:
# ['image_to_cells_labelme_vivax.jl']

# %%
image_to_cells_true.jl
